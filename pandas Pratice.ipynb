# %%
print("Pandas Pratice !")
# Out:
# Pandas Pratice !

# %%
import pandas as pd

# %%
data = {
     'a':1,
     'b':2,
     'c':3
}

# %%
data
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
data.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
data.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
data.values()
# Out:
# dict_values([1, 2, 3])

# %%
s = {v:k for k,v in data.items()}

# %%
s
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
# df = pd.DataFrame(s)

# %%
data = {
    "name": ['Dev','aman','babu'],
    "age" : [19,17,20]
    
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    name  age
# 0   Dev   19
# 1  aman   17
# 2  babu   20

# %%
df.tail()
# Out:
#    name  age
# 0   Dev   19
# 1  aman   17
# 2  babu   20

# %%
df.shape
# Out:
# (3, 2)

# %%
df.columns
# Out:
# Index(['name', 'age'], dtype='str')

# %%
df.size
# Out:
# 6

# %%
df.sample
# Out:
# <bound method NDFrame.sample of    name  age
# 0   Dev   19
# 1  aman   17
# 2  babu   20>

# %%
df.all
# Out:
# <bound method DataFrame.all of    name  age
# 0   Dev   19
# 1  aman   17
# 2  babu   20>

# %%
df.any
# Out:
# <bound method DataFrame.any of    name  age
# 0   Dev   19
# 1  aman   17
# 2  babu   20>

# %%
# df.mean()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      str
#  1   age     3 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 180.0 bytes

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   18.666667
# std     1.527525
# min    17.000000
# 25%    18.000000
# 50%    19.000000
# 75%    19.500000
# max    20.000000

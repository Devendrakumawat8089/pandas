# %%
print("EDA")

# Data Types :-->
# 1). Numberical Data --> Continuous Data --> Age(Year , month , Days) , height , weight etc.
# 2). Categorical Data --> Descerate Data --> total number of Employee , Matrial Status Student Result
# Out:
# EDA

# %%
import numpy as np
import pandas as pd

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt #Visulization Library
import seaborn as sns #Matplotlib's Updated Version Library

# %%
# Part Of EDA
# 1). Univariate Analysis --> Analysis on a single indepedent column 
# 2). Bivariate Analysis --> Analysis on two Columns 
# 3). Multivariate Analysis --> Analysis on more than 2 columns

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# 1) Univariate Analysis

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
sns.countplot(x =df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# if we want to see actual values then we use value_counts()
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind='pie' , autopct = '%.2f')
# Out:
# <Axes: >

# %%
# if we have Numerical Data Then we Use Histogram Because it finds the distribution

# %%
plt.hist(x = df['Age'])
plt.show()

# %%
# 2 boxplot 
# for find our outliers 

# 1. Lower fence 
# 2. 20 % Data
# 3. IQR (inter Quartile Range)(75%-25%)
# 4. 75% data 
# 5. Upper Fence

# %%
# x = 1,2,3,4,5
# mean() --> (1+2+3+4+5)/5 = 15/3  = 3 
# x = 1,2,3,4,5,100
# mean() --> 15+100/ 6 = 115/6 = 19.3

# %%
sns.boxplot(x = df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# scatterplot (NUmberical Column - NUmberical Column )
sns.scatterplot(x=tips['total_bill'],y=tips['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue = tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
print("Pandas Revision")
# Out:
# Pandas Revision

# %%
import pandas as pd

# %%
df = pd.read_csv("Hotes.csv")

# %%
df
# Out:
#                                            BMQDV href  \
# 0   https://www.tripadvisor.in/Hotel_Review-g29768...
# 1   https://www.tripadvisor.in/Hotel_Review-g29768...
# 2   https://www.tripadvisor.in/Hotel_Review-g29768...
# 3   https://www.tripadvisor.in/Hotel_Review-g29768...
# 4   https://www.tripadvisor.in/Hotel_Review-g29768...
# 5   https://www.tripadvisor.in/Hotel_Review-g29768...
# 6   https://www.tripadvisor.in/Hotel_Review-g29768...
# 7   https://www.tripadvisor.in/Hotel_Review-g29768...
# 8   https://www.tripadvisor.in/Hotel_Review-g29768...
# 9   https://www.tripadvisor.in/Hotel_Review-g29768...
# 10  https://www.tripadvisor.in/Hotel_Review-g29768...
# 11  https://www.tripadvisor.in/Hotel_Review-g29768...
# 12  https://www.tripadvisor.in/Hotel_Review-g29768...
# 13  https://www.tripadvisor.in/Hotel_Review-g29768...
# 14  https://www.tripadvisor.in/Hotel_Review-g29768...
# 15  https://www.tripadvisor.in/Hotel_Review-g29768...
# ...

# %%
df.isnull()
# Out:
#     BMQDV href  NhWcC src  biGQs  biGQs 2  evwcZ  BMQDV href 3  biGQs 3  \
# 0        False      False  False    False  False         False    False
# 1        False      False  False    False  False         False    False
# 2        False      False  False    False  False         False    False
# 3        False      False  False    False  False         False    False
# 4        False      False  False    False  False         False    False
# 5        False      False  False    False  False         False    False
# 6        False      False  False    False  False         False    False
# 7        False      False  False    False  False         False    False
# 8        False      False  False    False  False         False    False
# 9        False      False  False    False  False         False    False
# 10       False      False  False    False  False         False    False
# 11       False      False  False    False  False         False    False
# ...

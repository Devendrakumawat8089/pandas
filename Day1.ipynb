# %%
print("Hello World !")
# Out:
# Hello World !

# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# pandas --> pandas it

# %%
import pandas as pd

# %%
# Data Structure of pandas-->
# (1). Series --> it stores only values not column and it is one dimantional 
# (2). Dataframe -->it st

# %%
a =pd.Series([1,45,78,90])

# %%
print(type(a))
# Out:
# <class 'pandas.Series'>

# %%
# DataFrame

# %%
a ={
    'Emp_id' : [1,2,3,4,5],
    'Name' : ['sam','Mohit','Raj','Rahuel','Ankiet'],
    "Department" : ['it','sales','it','it','sales'],
    "Salary" : [20000,25000,30000,31000,26000]
}

# %%
df = pd.DataFrame(a)
df
# Out:
#    Emp_id    Name Department  Salary
# 0       1     sam         it   20000
# 1       2   Mohit      sales   25000
# 2       3     Raj         it   30000
# 3       4  Rahuel         it   31000
# 4       5  Ankiet      sales   26000

# %%
# Export Data into csv

# %%
df.to_csv("Emp_data.csv")

# %%
# Export Data into Exel

# %%
# df.to_excel("New_Emp_Data.xlsx")

# %%
# Import the data

# %%
a =pd.read_csv("C:\\Users\\HP\\OneDrive\\Desktop\\Python_Regex\\Pandas\\pandas\\phones_data.csv")
a.head(1)
# Out:
#                                          k7wcnx href  \
# 0  https://www.flipkart.com/google-pixel-9a-porce...
#
#                                           UCc1lI src          fU6cHR  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
#
#                                 RG5Slk  MKiFS6  \
# 0  Google Pixel 9A (Porcelain, 256 GB)     4.5
#
#                                           PZfbSE src         PvbNMB o2SIOJ  \
# 0  ......  8,289 Ratings      &
#
#       PvbNMB 2                 DTBslk  ...             DTBslk 5  \
# 0  548 Reviews  8 GB RAM | 256 GB ROM  ...  Tensor G4 Processor
#
#                    DTBslk 6   hZ3P6w   kRYCnD   HQe8jr  \
# 0  1 Year Domestic Warranty  ₹39,999  ₹49,999  20% off
#
#                                           qYp2rh src HZ0E6r HZ0E6r 2  \
# 0  https://static-assets-web.flixcart.com/fk-p-li...   Upto  ₹32,900
#
#           HZ0E6r 3    HZ0E6r 4
# 0  Off on Exchange  Bank Offer
#
# [1 rows x 23 columns]

# %%
a =pd.read_csv("C:\\Users\\HP\\OneDrive\\Desktop\\Python_Regex\\Pandas\\pandas\\Emp_data.csv")
a.head(5)
# Out:
#    Unnamed: 0  Emp_id    Name Department  Salary
# 0           0       1     sam         it   20000
# 1           1       2   Mohit      sales   25000
# 2           2       3     Raj         it   30000
# 3           3       4  Rahuel         it   31000
# 4           4       5  Ankiet      sales   26000
